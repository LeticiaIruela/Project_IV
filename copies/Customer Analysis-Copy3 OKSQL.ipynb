# %%
import os
import datetime
import warnings
import pandas as pd 
import numpy as np
import datetime as dt
from operator import attrgetter
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import sqlalchemy as alch
from getpass import getpass

# %% [markdown]
# What are CRM Analytics?
#
# CRM analytics are data that demonstrate your company’s sales and customer service performance. CRM analytics also presents customer data that you can use to inform smarter business decisions. Typically, you’ll use CRM software to obtain CRM analytics and automate all your data collection and report generation.
#
# Benefits of CRM Analysis
#
# The primary benefit of CRM analysis is that you can use it to inform your sales, customer service and marketing processes. You can use your CRM analytics to improve your methods via:
#
# Customer service evaluations. CRM analytics fill you in on your customer service team’s performance. If you see figures that your team could improve, implement practices that push your team toward these goals.
# Accurate customer data. Whether you’re using your customer data for demographic marketing or email marketing, you need to know whether you’re reaching the right person. CRM analysis ensures you’re doing just that.
# Thorough customer analytics. How much does your customer usually spend per quarter with you? Are they buying the same products time and time again, or does it vary? With CRM analytics, you’ll get firm answers to these questions, and you can use what you learn to refine your marketing strategies.
# Efficient lead generation. Your CRM analysis can tell you which of your marketing efforts most strongly correlate to purchases. If you see one approach correlating strongly to purchases but have only targeted a sliver of your customers with that approach, try that method more – your sales might increase.

# %% [markdown]
# Context- A superstore is planning for the ens season sale. They want to launch a new offer - gold membership, that gives a 20% discount on all purchases, for only $499 which is $999 on other days. It will be valid only for existing customers and the campaign through phone calls is currently being planned for them. The management feels that the best way to reduce the cost of the campaign is to make a predictive model which will classify customers who might purchase the offer.
# Objective - The superstore wants to predict the likelihood of the customer giving a positive response and wants to identify the different factors which affect the customer's response. You need to analyze the data provided to identify these factors and then build a prediction model to predict the probability of a customer will give a positive response.

# %%
df=pd.read_csv('dataset/superstore.csv',encoding='latin-1')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class  \
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City
# ...

# %%
nan_count = df.isna().sum()
print(nan_count)
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.sample()
df.shape
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
def unique_values (df):
    unique_values = {}
    for column in df.columns:
        unique_values[column] = df[column].unique()
    for column, unique_values in unique_values.items():
        print(f"{column}:")
        print(unique_values)
        print()

# %%
def verifystring (df, column_name):
    unique_values = df[column_name].unique()
    allstring = all(isinstance(x, str) for x in unique_values)
    if allstring:
        print("All values are strings")
    else:
        print("Not only strings in the column")

# %%
verif=verifystring (df,'Order Date')
# Out:
# All values are strings

# %%
unique_valuess= unique_values (df)
# Out:
# Row ID:
# [   1    2    3 ... 9992 9993 9994]
#
# Order ID:
# ['CA-2016-152156' 'CA-2016-138688' 'US-2015-108966' ... 'CA-2014-110422'
#  'CA-2017-121258' 'CA-2017-119914']
#
# Order Date:
# ['11/8/2016' '6/12/2016' '10/11/2015' ... '6/3/2016' '4/12/2015'
#  '1/21/2014']
#
# Ship Date:
# ['11/11/2016' '6/16/2016' '10/18/2015' ... '5/23/2015' '1/23/2014'
#  '3/3/2017']
#
# Ship Mode:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
#
# Customer ID:
# ['CG-12520' 'DV-13045' 'SO-20335' 'BH-11710' 'AA-10480' 'IM-15070'
#  'HP-14815' 'PK-19075' 'AG-10270' 'ZD-21925' 'KB-16585' 'SF-20065'
#  'EB-13870' 'EH-13945' 'TB-21520' 'MA-17560' 'GH-14485' 'SN-20710'
#  'LC-16930' 'RA-19885' 'ES-14080' 'ON-18715' 'PO-18865' 'LH-16900'
#  'DP-13000' 'JM-15265' 'TB-21055' 'KM-16720' 'PS-18970' 'BS-11590'
#  'KD-16270' 'HM-14980' 'JE-15745' 'KB-16600' 'SC-20770' 'DN-13690'
#  'JC-16105' 'CS-12400' 'PG-18895' 'GM-14455' 'JS-15685' 'KB-16315'
# ...

# %%
#%%script false
def cleaning(df):
    df1 = df.drop_duplicates()
    df1 = df.dropna()
    df1 = df.drop('Row ID', axis=1)
    return df1

# %%
df1 = cleaning(df)
df1.sample()
# Out:
#             Order ID Order Date Ship Date     Ship Mode Customer ID
# 1042  CA-2016-102981   9/6/2016  9/9/2016  Second Class    MO-17500  \
#
#       Customer Name   Segment        Country           City     State
# 1042  Mary O'Rourke  Consumer  United States  New York City  New York  \
#
#       Postal Code Region       Product ID   Category Sub-Category
# 1042        10035   East  FUR-BO-10001811  Furniture    Bookcases  \
#
#                                            Product Name    Sales  Quantity
# 1042  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...  722.352         3  \
#
#       Discount  Profit
# 1042       0.2  90.294

# %%
def round_numerical (df, columns):
    df[columns]=df[columns].round(2)
    return df

# %%
df2=round_numerical (df1, ['Sales','Profit'])
df2.sample()
# Out:
#            Order ID Order Date  Ship Date     Ship Mode Customer ID
# 401  CA-2016-108987   9/8/2016  9/10/2016  Second Class    AG-10675  \
#
#     Customer Name   Segment        Country     City  State  Postal Code
# 401   Anna Gayman  Consumer  United States  Houston  Texas        77036  \
#
#       Region       Product ID    Category Sub-Category
# 401  Central  TEC-AC-10000158  Technology  Accessories  \
#
#                                       Product Name  Sales  Quantity  Discount
# 401  Sony 64GB Class 10 Micro SDHC R40 Memory Card  57.58         2       0.2  \
#
#      Profit
# 401    0.72

# %%
nan_count = df2.isna().sum()
print(nan_count)
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df2.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.857980     3.789574     0.156203    28.656848
# std    32063.693350    623.245104     2.225110     0.206452   234.260149
# min     1040.000000      0.440000     1.000000     0.000000 -6599.980000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.730000
# 50%    56430.500000     54.490000     3.000000     0.200000     8.665000
# 75%    90008.000000    209.940000     5.000000     0.200000    29.360000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.980000

# %%
df2['Order Date'] = pd.to_datetime(df2['Order Date'], format='%m/%d/%Y')
df2
# Out:
#             Order ID Order Date   Ship Date       Ship Mode Customer ID
# 0     CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520  \
# 1     CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# ...              ...        ...         ...             ...         ...
# 9989  CA-2014-110422 2014-01-21   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State
# ...

# %%
df2.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date                object
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
def extract_date_parts(df,columns):
    for column in columns:
        df[column + '_Year'] = pd.to_datetime(df[column], format='%m/%d/%Y').dt.year
        df[column + '_Month'] = pd.to_datetime(df[column], format='%m/%d/%Y').dt.month
        df[column + '_Day'] = pd.to_datetime(df[column], format='%m/%d/%Y').dt.day
    return df

# %%
df3 = extract_date_parts(df2, ['Order Date', 'Ship Date'])
df3
# Out:
#             Order ID Order Date   Ship Date       Ship Mode Customer ID
# 0     CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520  \
# 1     CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# ...              ...        ...         ...             ...         ...
# 9989  CA-2014-110422 2014-01-21   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State
# ...

# %%
df3.to_csv('dataset/df_cleaned2.csv')

# %%
#def connection_sql (password,dbname):
    connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
    engine = alch.create_engine(connectionData)
    return engine
# Out:
#   Cell In[20], line 2
#     connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
#     ^
# IndentationError: unexpected indent

# %%
#df2.to_sql('df_cleaned1', con=engine, if_exists='replace', index=False)

# %%
#df = pd.read_sql_query("SELECT * FROM df_cleaned2;", engine)

# %%
#engine = connection_sql(password, "superstore")

# %%
import sqlalchemy as alch
from getpass import getpass
password = getpass("Please input your password: ")

dbName = "superstoresata"
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"

engine = alch.create_engine(connectionData)

df2.to_sql('df_cleaned2', con=engine, if_exists='replace', index=False)
# Out:
# Please input your password: ········
# 9994

# %%
#password=getpass()

# %%
query="SELECT * FROM df_cleaned2;"
df3 = pd.read_sql(query, engine)
df3.sample()
# Out:
#             Order ID Order Date Ship Date       Ship Mode Customer ID
# 3609  CA-2014-140228 2014-04-28  5/3/2014  Standard Class    GB-14530  \
#
#      Customer Name    Segment        Country    City State  ...  Sales
# 3609   George Bell  Corporate  United States  Newark  Ohio  ...   27.1  \
#
#      Quantity Discount Profit Order Date_Year Order Date_Month
# 3609        3      0.2   2.03            2014                4  \
#
#       Order Date_Day  Ship Date_Year  Ship Date_Month  Ship Date_Day
# 3609              28            2014                5              3
#
# [1 rows x 26 columns]

# %% [markdown]
# # RFM Analysis
#
# RFM stands for Recency, Frequency, and Monetary value, each corresponding to some key customer trait. These RFM metrics are important indicators of a customer’s behavior because frequency and monetary value affects a customer’s lifetime value, and recency affects retention, a measure of engagement.
#
# RFM factors illustrate these facts:
#
# - The more recent the purchase, the more responsive the customer is to promotions
# - The more frequently the customer buys, the more engaged and satisfied they are
# - Monetary value differentiates heavy spenders from low-value purchasers

# %%
query='''
    SHOW COLUMNS FROM df_cleaned2 LIKE 'Order Date';
'''
pd.read_sql_query (query, engine)
# Out:
#         Field      Type Null Key Default Extra
# 0  Order Date  datetime  YES        None

# %%
query = '''
    SELECT YEAR(`Order Date`) AS Year, Category, SUM(Sales) AS TotalSold, SUM(Quantity) as TotalQuantity
    FROM df_cleaned2
    GROUP BY Category, YEAR(`Order Date`)
    ORDER BY Year DESC;
'''
pd.read_sql_query (query, engine)
# Out:
#     Year         Category  TotalSold  TotalQuantity
# 0   2017  Office Supplies  246097.08         7676.0
# 1   2017        Furniture  215387.18         2437.0
# 2   2017       Technology  271730.79         2363.0
# 3   2016        Furniture  198901.47         2193.0
# 4   2016  Office Supplies  183940.05         5946.0
# 5   2016       Technology  226364.22         1698.0
# 6   2015        Furniture  170518.22         1775.0
# 7   2015  Office Supplies  137233.40         4715.0
# 8   2015       Technology  162780.77         1489.0
# 9   2014        Furniture  157192.86         1623.0
# 10  2014  Office Supplies  151776.37         4569.0
# 11  2014       Technology  175278.24         1389.0

# %%
query='''
SELECT MAX(`Order Date`) AS MaxOrderDate
FROM df_cleaned2;
'''
pd.read_sql_query (query, engine)
# Out:
#   MaxOrderDate
# 0   2017-12-30

# %%
query='''
ALTER TABLE df_cleaned2
ADD COLUMN Recency INT,
ADD COLUMN Frequency INT,
ADD COLUMN Monetary DECIMAL(10, 2);
'''
pd.read_sql_query (query, engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[29], line 7
#       1 query='''
#       2 ALTER TABLE df_cleaned2
#       3 ADD COLUMN Recency INT,
#       4 ADD COLUMN Frequency INT,
#       5 ADD COLUMN Monetary DECIMAL(10, 2);
#       6 '''
# ----> 7 pd.read_sql_query (query, engine)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\io\sql.py:467, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     464     dtype_backend = "numpy"  # type: ignore[assignment]
#     466 with pandasSQL_builder(con) as pandas_sql:
# --> 467     return pandas_sql.read_query(
#     468         sql,
#     469         index_col=index_col,
#     470         params=params,
#     471         coerce_float=coerce_float,
#     472         parse_dates=parse_dates,
#     473         chunksize=chunksize,
# ...

# %%
query = '''
UPDATE df_cleaned2 AS t
JOIN (
    SELECT
        `Customer ID`,
        DATEDIFF('2018-01-30', MAX(`Order Date`)) AS Recency,
        COUNT(*) AS Frequency,
        SUM(`Sales`) AS Monetary
    FROM df_cleaned2
    GROUP BY `Customer ID`
) AS subquery ON t.`Customer ID` = subquery.`Customer ID`
SET t.Recency = subquery.Recency,
    t.Frequency = subquery.Frequency,
    t.Monetary = subquery.Monetary
'''
with engine.begin() as conn:
    conn.execute(query)

# %%
query="SELECT * FROM df_cleaned2;"
df10 = pd.read_sql(query, engine)
df10.sample()
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID
# 6334  CA-2014-133305 2014-07-11  7/15/2014  Standard Class    MH-17455  \
#
#       Customer Name   Segment        Country           City     State  ...
# 6334  Mark Hamilton  Consumer  United States  New York City  New York  ...  \
#
#       Profit Order Date_Year Order Date_Month Order Date_Day Ship Date_Year
# 6334   23.09            2014                7             11           2014  \
#
#      Ship Date_Month  Ship Date_Day  Recency  Frequency  Monetary
# 6334               7             15      116         11   2456.18
#
# [1 rows x 29 columns]

# %% [markdown]
# ubconsulta para obtener los valores mínimos y máximos de cada columna y luego unirlo con la consulta principal. Modifica tu consulta de la siguiente manera:La fórmula (Columna - MIN(Columna)) / (MAX(Columna) - MIN(Columna)) normaliza los valores de cada columna en el rango de 0 a 1.
#
# Esta consulta te dará los valores normalizados de las columnas Recency, Frequency y Monetary, junto con el CustomerID asociado a cada registro.

# %%
#alter_query = '''
ALTER TABLE df_cleaned2
ADD COLUMN NormalizedRecency DECIMAL(10, 2),
ADD COLUMN NormalizedFrequency DECIMAL(10, 2),
ADD COLUMN NormalizedMonetary DECIMAL(10, 2);
'''

# Ejecutar la sentencia ALTER TABLE
with engine.begin() as conn:
    conn.execute(alter_query)

# %%
query='''
SHOW COLUMNS FROM df_cleaned2;
'''
pd.read_sql_query (query, engine)
# Out:
#                   Field           Type Null Key Default Extra
# 0              Order ID           text  YES        None
# 1            Order Date       datetime  YES        None
# 2             Ship Date           text  YES        None
# 3             Ship Mode           text  YES        None
# 4           Customer ID           text  YES        None
# 5         Customer Name           text  YES        None
# 6               Segment           text  YES        None
# 7               Country           text  YES        None
# 8                  City           text  YES        None
# 9                 State           text  YES        None
# 10          Postal Code         bigint  YES        None
# 11               Region           text  YES        None
# 12           Product ID           text  YES        None
# 13             Category           text  YES        None
# 14         Sub-Category           text  YES        None
# 15         Product Name           text  YES        None
# ...

# %%
update_query = '''
UPDATE df_cleaned2 AS t
JOIN (
    SELECT 
        MIN(Recency) AS MinRecency,
        MAX(Recency) AS MaxRecency,
        MIN(Frequency) AS MinFrequency,
        MAX(Frequency) AS MaxFrequency,
        MIN(Monetary) AS MinMonetary,
        MAX(Monetary) AS MaxMonetary
    FROM df_cleaned2
) AS min_vals
CROSS JOIN (
    SELECT 
        MIN(Recency) AS MinRecency,
        MAX(Recency) AS MaxRecency,
        MIN(Frequency) AS MinFrequency,
        MAX(Frequency) AS MaxFrequency,
        MIN(Monetary) AS MinMonetary,
        MAX(Monetary) AS MaxMonetary
    FROM df_cleaned2
) AS max_vals
SET t.NormalizedRecency = (t.Recency - min_vals.MinRecency) / (max_vals.MaxRecency - min_vals.MinRecency),
    t.NormalizedFrequency = (t.Frequency - min_vals.MinFrequency) / (max_vals.MaxFrequency - min_vals.MinFrequency),
    t.NormalizedMonetary = (t.Monetary - min_vals.MinMonetary) / (max_vals.MaxMonetary - min_vals.MinMonetary);
'''

# Ejecutar la sentencia UPDATE
with engine.begin() as conn:
    conn.execute(update_query)

# %%
query="SELECT * FROM df_cleaned2;"
df11 = pd.read_sql(query, engine)
df11.sample()
# Out:
#             Order ID Order Date  Ship Date     Ship Mode Customer ID
# 2922  US-2015-141453 2015-11-30  12/3/2015  Second Class    DB-13270  \
#
#           Customer Name      Segment        Country    City  State  ...
# 2922  Deborah Brumfield  Home Office  United States  Austin  Texas  ...  \
#
#       Order Date_Day Ship Date_Year Ship Date_Month Ship Date_Day Recency
# 2922              30           2015              12             3      84  \
#
#      Frequency  Monetary  NormalizedRecency  NormalizedFrequency
# 2922        13   4655.89               0.05                 0.33  \
#
#       NormalizedMonetary
# 2922                0.19
#
# [1 rows x 32 columns]

# %%
#alter_query1 = '''
ALTER TABLE df_cleaned2
ADD COLUMN RecencyScore INT,
ADD COLUMN FrequencyScore INT,
ADD COLUMN MonetaryScore INT;
'''
with engine.begin() as conn:
    conn.execute(alter_query1)

# %%
query = '''
UPDATE df_cleaned2 AS t
SET RecencyScore = 
    CASE
        WHEN t.NormalizedRecency <= 0.2 THEN 5
        WHEN t.NormalizedRecency <= 0.4 THEN 4
        WHEN t.NormalizedRecency <= 0.6 THEN 3
        WHEN t.NormalizedRecency <= 0.8 THEN 2
        ELSE 1
    END,
    FrequencyScore = 
    CASE
        WHEN t.NormalizedFrequency <= 0.2 THEN 1
        WHEN t.NormalizedFrequency <= 0.4 THEN 2
        WHEN t.NormalizedFrequency <= 0.6 THEN 3
        WHEN t.NormalizedFrequency <= 0.8 THEN 4
        ELSE 5
    END,
    MonetaryScore = 
    CASE
        WHEN t.NormalizedMonetary <= 0.2 THEN 1
        WHEN t.NormalizedMonetary <= 0.4 THEN 2
        WHEN t.NormalizedMonetary <= 0.6 THEN 3
        WHEN t.NormalizedMonetary <= 0.8 THEN 4
        ELSE 5
    END;
'''

with engine.begin() as conn:
    conn.execute(query)

# %%
query="SELECT * FROM df_cleaned2;"
df12 = pd.read_sql(query, engine)
df12.sample()
# Out:
#             Order ID Order Date  Ship Date     Ship Mode Customer ID
# 5648  CA-2017-142342 2017-07-17  7/19/2017  Second Class    AJ-10795  \
#
#         Customer Name    Segment        Country          City       State
# 5648  Anthony Johnson  Corporate  United States  Apple Valley  California  \
#
#       ...  Ship Date_Day Recency Frequency Monetary NormalizedRecency
# 5648  ...             19     197        21  4501.38              0.14  \
#
#      NormalizedFrequency  NormalizedMonetary  RecencyScore  FrequencyScore
# 5648                0.56                0.18             5               3  \
#
#       MonetaryScore
# 5648              1
#
# [1 rows x 35 columns]

# %%
query='''ALTER TABLE df_cleaned2
ADD COLUMN `RFM_Score` INT;
'''
pd.read_sql(query, engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[40], line 4
#       1 query='''ALTER TABLE df_cleaned2
#       2 ADD COLUMN `RFM_Score` INT;
#       3 '''
# ----> 4 pd.read_sql(query, engine)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\io\sql.py:661, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     651     return pandas_sql.read_table(
#     652         sql,
#     653         index_col=index_col,
#    (...)
#     658         dtype_backend=dtype_backend,
#     659     )
#     660 else:
# --> 661     return pandas_sql.read_query(
#     662         sql,
#     663         index_col=index_col,
#     664         params=params,
#     665         coerce_float=coerce_float,
#     666         parse_dates=parse_dates,
#     667         chunksize=chunksize,
# ...

# %%
#query='''
UPDATE df_cleaned2
SET `RFM_Score` = CONCAT(RecencyScore,FrequencyScore,MonetaryScore);
'''
pd.read_sql_query (query, engine)
# Out:
#   Cell In[48], line 4
#     '''
#     ^
# SyntaxError: unterminated triple-quoted string literal (detected at line 5)

# %%
query = "SELECT * FROM df_cleaned2;"
result = pd.read_sql_query(query, engine)
result
# Out:
#             Order ID Order Date   Ship Date       Ship Mode Customer ID
# 0     CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520  \
# 1     CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# ...              ...        ...         ...             ...         ...
# 9989  CA-2014-110422 2014-01-21   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State
# ...

# %%
query = '''
ALTER TABLE df_cleaned2 ADD Segments VARCHAR(50);
'''    
pd.read_sql_query(query, engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[50], line 4
#       1 query = '''
#       2 ALTER TABLE df_cleaned2 ADD Segments VARCHAR(50);
#       3 '''
# ----> 4 pd.read_sql_query(query, engine)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\io\sql.py:467, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     464     dtype_backend = "numpy"  # type: ignore[assignment]
#     466 with pandasSQL_builder(con) as pandas_sql:
# --> 467     return pandas_sql.read_query(
#     468         sql,
#     469         index_col=index_col,
#     470         params=params,
#     471         coerce_float=coerce_float,
#     472         parse_dates=parse_dates,
#     473         chunksize=chunksize,
#     474         dtype=dtype,
#     475         dtype_backend=dtype_backend,
#     476     )
#
# ...

# %%
query = '''
UPDATE df_cleaned2
SET Segments =
    CASE
        WHEN RFM_Score IN (555, 554, 544, 545, 454, 455, 445) THEN 'Champions'
        WHEN RFM_Score IN (543, 444, 435, 355, 354, 345, 344, 335) THEN 'Loyal customer'
        WHEN RFM_Score IN (553, 551, 552, 541, 542, 533, 532, 531, 452, 451, 442, 441, 431, 453, 433, 432, 423, 353, 352, 351, 342, 341, 333, 323) THEN 'Potential Loyalist'
        WHEN RFM_Score IN (512, 511, 422, 421, 412, 411, 311) THEN 'New Customers'
        WHEN RFM_Score IN (525, 524, 523, 522, 521, 515, 514, 513, 425, 424, 413, 414, 415, 315, 314, 313) THEN 'Promising'
        WHEN RFM_Score IN (535, 534, 443, 434, 343, 334, 325, 324) THEN 'Need Attention'
        WHEN RFM_Score IN (155, 154, 144, 214, 215, 115, 114, 113) THEN 'Cannot Lose Them'
        WHEN RFM_Score IN (331, 321, 312, 221, 213) THEN 'About to sleep'
        WHEN RFM_Score IN (255, 254, 245, 244, 253, 252, 243, 242, 235, 234, 225, 224, 153, 152, 145, 143, 142, 135, 134, 133, 125, 124) THEN 'At risk'
        WHEN RFM_Score IN (332, 322, 231, 241, 251, 233, 232, 223, 222, 132, 123, 122, 212, 211) THEN 'Hibernating'
        WHEN RFM_Score IN (111, 112, 121, 131, 141, 151) THEN 'Lost'
        ELSE 'Other'
    END;
'''    
pd.read_sql_query(query, engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[51], line 19
#       1 query = '''
#       2 UPDATE df_cleaned2
#       3 SET Segments =
#    (...)
#      17     END;
#      18 '''
# ---> 19 pd.read_sql_query(query, engine)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\io\sql.py:467, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     464     dtype_backend = "numpy"  # type: ignore[assignment]
#     466 with pandasSQL_builder(con) as pandas_sql:
# --> 467     return pandas_sql.read_query(
#     468         sql,
#     469         index_col=index_col,
#     470         params=params,
#     471         coerce_float=coerce_float,
#     472         parse_dates=parse_dates,
#     473         chunksize=chunksize,
#     474         dtype=dtype,
# ...

# %%
query = "SELECT * FROM df_cleaned2;"
result = pd.read_sql_query(query, engine)
# Out:
#             Order ID Order Date   Ship Date       Ship Mode Customer ID
# 0     CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520  \
# 1     CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# ...              ...        ...         ...             ...         ...
# 9989  CA-2014-110422 2014-01-21   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State
# ...

# %%
query='''SELECT Segments, 
       COUNT(DISTINCT `Customer ID`) AS TotalCustomers, 
       SUM(Profit) AS TotalProfit,
       ROUND(COUNT(DISTINCT `Customer ID`) / (SELECT COUNT(DISTINCT `Customer ID`) FROM df_cleaned2) * 100,1) AS CustomerPercentage
FROM df_cleaned2
GROUP BY Segments
ORDER BY TotalCustomers DESC;
'''
pd.read_sql_query(query, engine)
# Out:
#              Segments  TotalCustomers  TotalProfit  CustomerPercentage
# 0           Promising             307    120885.52                38.7
# 1       New Customers             242     35854.83                30.5
# 2  Potential Loyalist             208    117502.56                26.2
# 3         Hibernating              15      2260.51                 1.9
# 4      About to sleep              13      4646.21                 1.6
# 5                Lost               5       342.89                 0.6
# 6      Loyal customer               2      2970.26                 0.3
# 7      Need Attention               1      1933.76                 0.1

# %%
query='''
SELECT 
    Segments,
    CASE
        WHEN Discount > 0 THEN 'Discount applied'
        ELSE 'No discount'
    END AS DiscountStatus,
    `Sub-Category`,
    COUNT(`Sub-Category`) AS TotalQuantity,
    SUM(Sales) AS TotalSales,
    SUM(Profit) AS TotalProfit
FROM df_cleaned2
GROUP BY Segments, DiscountStatus, `Sub-Category`;
'''
pd.read_sql_query(query, engine)
# Out:
#            Segments    DiscountStatus Sub-Category  TotalQuantity  TotalSales
# 0     New Customers       No discount    Bookcases              9     3994.64  \
# 1     New Customers       No discount       Chairs             16    10450.44
# 2         Promising       No discount       Labels             97     3677.36
# 3         Promising  Discount applied       Tables            101    59787.07
# 4         Promising  Discount applied      Storage            123    24163.46
# ..              ...               ...          ...            ...         ...
# 214            Lost  Discount applied          Art              1       55.33
# 215            Lost       No discount          Art              1       20.65
# 216            Lost       No discount      Storage              1      204.90
# 217            Lost  Discount applied       Chairs              2      918.27
# 218  Need Attention       No discount       Phones              1      437.85
#
#      TotalProfit
# ...

# %%
query='''
SHOW VARIABLES LIKE 'secure_file_priv';

'''
pd.read_sql_query(query, engine)
# Out:
#       Variable_name                                           Value
# 0  secure_file_priv  C:\ProgramData\MySQL\MySQL Server 8.0\Uploads\

# %%
query='''
SELECT *
FROM df_cleaned2
INTO OUTFILE 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/df_SQL.csv'
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\n';
'''
pd.read_sql_query(query, engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[92], line 9
#       1 query='''
#       2 SELECT *
#       3 FROM df_cleaned2
#    (...)
#       7 LINES TERMINATED BY '\n';
#       8 '''
# ----> 9 pd.read_sql_query(query, engine)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\io\sql.py:467, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     464     dtype_backend = "numpy"  # type: ignore[assignment]
#     466 with pandasSQL_builder(con) as pandas_sql:
# --> 467     return pandas_sql.read_query(
#     468         sql,
#     469         index_col=index_col,
#     470         params=params,
#     471         coerce_float=coerce_float,
#     472         parse_dates=parse_dates,
#     473         chunksize=chunksize,
#     474         dtype=dtype,
# ...

# %%
query='''
SELECT *
FROM df_cleaned2
INTO OUTFILE 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/df_SQL2.csv'
FIELDS TERMINATED BY ';'
ENCLOSED BY '"'
LINES TERMINATED BY '\n';
'''
pd.read_sql_query(query, engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[95], line 9
#       1 query='''
#       2 SELECT *
#       3 FROM df_cleaned2
#    (...)
#       7 LINES TERMINATED BY '\n';
#       8 '''
# ----> 9 pd.read_sql_query(query, engine)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\io\sql.py:467, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     464     dtype_backend = "numpy"  # type: ignore[assignment]
#     466 with pandasSQL_builder(con) as pandas_sql:
# --> 467     return pandas_sql.read_query(
#     468         sql,
#     469         index_col=index_col,
#     470         params=params,
#     471         coerce_float=coerce_float,
#     472         parse_dates=parse_dates,
#     473         chunksize=chunksize,
#     474         dtype=dtype,
# ...

# %%
import pandas as pd

# Ejecutar la consulta SQL y guardar el resultado en un DataFrame
df = pd.read_sql_query("SELECT * FROM df_cleaned2", engine)

# Agregar una fila con los nombres de las columnas al DataFrame
df_with_header = pd.concat([pd.Series(df.columns), df], ignore_index=True)

# Guardar el DataFrame con los nombres de las columnas en un archivo CSV
df_with_header.to_csv('dataset/df_SQL1.csv', index=False)

# %% [markdown]
# Una vez que tienes los valores normalizados de Recency, Frequency y Monetary en el rango de 0 a 1, puedes calcular el RFM Score sumando los valores normalizados de cada componente.
#
# El RFM Score es una forma de combinar las tres métricas (Recency, Frequency, Monetary) en un solo número que representa el valor de un cliente. Puedes asignar un peso a cada componente para ajustar su importancia relativa en el cálculo del RFM Score. Por ejemplo, puedes asignar un peso del 40% a Recency, un peso del 30% a Frequency y un peso del 30% a Monetary.

# %% [markdown]
# # Distribution of Numerical columns:
#
# - Histplot:
#     A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within disrete bins.
# - Boxplot:
#     A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are.
# - Kdeplot:
#     A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.

# %% [markdown]
# Distribution of Sales

# %% [markdown]
# Distribution of Profit

# %% [markdown]
# Distribution of Quantity: https://www.kaggle.com/code/ashwinshetgaonkar/super-store-analysis-data-visual-seaborn/notebook

# %% [markdown]
# Distribution of Discount

# %% [raw]
# line plot:
# Average Sales , Profit and Quantity sold over Time Period(2014-2018)

# %% [markdown]
# Sales vs Profit for Time Period(2014-2018)

# %% [markdown]
# ¿Quiénes son tus mejores clientes?
# ¿Cuáles son tus clientes más leales?
# ¿Quiénes están cerca de abandonar tu marca o tu eCommerce?
# ¿Cuáles son los clientes considerados como perdidos a los que no debes prestar demasiada atención?
# ¿En qué clientes es rentable invertir esfuerzo extra para conservarlos?
# ¿Qué segmento de clientes reaccionará de forma favorable ante tu próxima campaña, o la actual?

# %% [markdown]
# Las anteriores respuestas constituyen el punto de partida para diseñar estrategias, y como consecuencia son capaces de conseguir los siguientes beneficios:
#
# Más eficiencia: optimización de las acciones de marketing y de su impacto.
# Mayor conversión: Incremento del CVR.
# Mejor fidelización: mayor retención de clientes y por más tiempo.
# Más interacción: aumento de la tasa de respuesta.
# Mayores ingresos: crecimiento de las ventas.

# %% [markdown]
# acciones de marketing a segmentos de clientes estratégicos, ganar impacto, aumentar la rentabilidad y mejorar la eficiencia de las acciones de marketing.
